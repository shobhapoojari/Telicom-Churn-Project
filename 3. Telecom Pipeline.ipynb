# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
telecom = pd.read_csv("Churn Final_data.csv")
telecom.head(3)
# Out:
#    Unnamed: 0  account_length  voice_mail_messages  customer_service_calls  \
# 0           0             128                   25                       1
# 1           1             107                   26                       1
# 2           2             137                    0                       0
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# 0                   0        110       45.07             99           16.78
# 1                   0        123       27.47            103           16.62
# 2                   0        114       41.38            110           10.30
#
#    night_calls  night_charge  international_calls  international_charge  \
# 0           91         11.01                    3                  2.70
# 1          103         11.45                    3                  3.70
# 2          104          7.32                    5                  3.29
#
#    total_charge  churn
# 0         75.56      0
# ...

# %%
telecom = telecom.drop("Unnamed: 0",axis=1)

# %%
telecom.head()
# Out:
#    account_length  voice_mail_messages  customer_service_calls  \
# 0             128                   25                       1
# 1             107                   26                       1
# 2             137                    0                       0
# 3              84                    0                       2
# 4              75                    0                       3
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# 0                   0        110       45.07             99           16.78
# 1                   0        123       27.47            103           16.62
# 2                   0        114       41.38            110           10.30
# 3                   1         71       50.90             88            5.26
# 4                   1        113       28.34            122           12.61
#
#    night_calls  night_charge  international_calls  international_charge  \
# ...

# %%
telecom.shape
# Out:
# (5700, 14)

# %%
X = telecom.drop("churn",axis=1)
y = telecom["churn"]

# %%
X
# Out:
#       account_length  voice_mail_messages  customer_service_calls  \
# 0                128                   25                       1
# 1                107                   26                       1
# 2                137                    0                       0
# 3                 84                    0                       2
# 4                 75                    0                       3
# ...              ...                  ...                     ...
# 5695              75                    0                       1
# 5696             115                    0                       2
# 5697             145                    0                       1
# 5698              69                   33                       1
# 5699             123                    0                       4
#
#       international_plan  day_calls  day_charge  evening_calls  \
# 0                      0        110       45.07             99
# ...

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
X.columns
# Out:
# Index(['account_length', 'voice_mail_messages', 'customer_service_calls',
#        'international_plan', 'day_calls', 'day_charge', 'evening_calls',
#        'evening_charge', 'night_calls', 'night_charge', 'international_calls',
#        'international_charge', 'total_charge'],
#       dtype='object')

# %%
classifier = []
classifier.append(('standardize', StandardScaler()))
classifier.append(("model",RandomForestClassifier()))

# %%
classifier
# Out:
# [('standardize', StandardScaler()), ('model', RandomForestClassifier())]

# %%
model= Pipeline(classifier)

# %%
model
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('model', RandomForestClassifier())])

# %%
X
# Out:
#       account_length  voice_mail_messages  customer_service_calls  \
# 0                128                   25                       1
# 1                107                   26                       1
# 2                137                    0                       0
# 3                 84                    0                       2
# 4                 75                    0                       3
# ...              ...                  ...                     ...
# 5695              75                    0                       1
# 5696             115                    0                       2
# 5697             145                    0                       1
# 5698              69                   33                       1
# 5699             123                    0                       4
#
#       international_plan  day_calls  day_charge  evening_calls  \
# 0                      0        110       45.07             99
# ...

# %%
model.fit(X,y)
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('model', RandomForestClassifier())])

# %% [markdown]
# # Model Saving

# %%
import pickle

# %%
f1 = open("Churn_Final_Model.pkl",mode="wb")

# %%
pickle.dump(model,f1)

# %%
f1.close()

# %% [markdown]
# # User Testing

# %%
X.iloc[1,:]
# Out:
# account_length            107.00
# voice_mail_messages        26.00
# customer_service_calls      1.00
# international_plan          0.00
# day_calls                 123.00
# day_charge                 27.47
# evening_calls             103.00
# evening_charge             16.62
# night_calls               103.00
# night_charge               11.45
# international_calls         3.00
# international_charge        3.70
# total_charge               59.24
# Name: 1, dtype: float64

# %%
data = {"account_length": 107.00,
       "voice_mail_messages": 26.00,
        "customer_service_calls": 1.00,
        "international_plan": 0.00,
        "day_calls": 123.00,
        "day_charge": 27.47,
        "evening_calls": 103.00,
        "evening_charge": 16.62,
        "night_calls": 103.00,
        "night_charge": 11.45,
        "international_calls": 3.00,
        "international_charge": 3.70,
        "total_charge": 59.24,
             
              }

# %%
telecom["account_length"].unique()
# Out:
# array([128, 107, 137,  84,  75, 118, 121, 147, 117, 141,  65,  74, 168,
#         95,  62, 161,  85,  93,  76,  73,  77, 130, 111, 132, 174,  57,
#         54,  20,  49, 142, 172,  12,  72,  36,  78, 136, 149,  98, 135,
#         34, 160,  64,  59, 119,  97,  52,  60,  10,  96,  87,  81,  68,
#        125, 116,  38,  40,  43, 113, 126, 150, 138, 162,  90,  50,  82,
#        144,  46,  70,  55, 106,  94, 155,  80, 104,  99, 120, 108, 122,
#        157, 103,  63, 112,  41, 193,  61,  92, 131, 163,  91, 127, 110,
#        140,  83, 145,  56, 151, 139,   6, 115, 146, 185, 148,  32,  25,
#        179,  67,  19, 170, 164,  51, 208,  53, 105,  66,  86,  35,  88,
#        123,  45, 100, 215,  22,  33, 114,  24, 101, 143,  48,  71, 167,
#         89, 199, 166, 158, 196, 209,  16,  39, 173, 129,  44,  79,  31,
#        124,  37, 159, 194, 154,  21, 133, 224,  58,  11, 109, 102, 165,
#         18,  30, 176,  47, 190, 152,  26,  69, 186, 171,  28, 153, 169,
# ...

# %%
new_user = pd.DataFrame(data,index=[0])
new_user
# Out:
#    account_length  voice_mail_messages  customer_service_calls  \
# 0           107.0                 26.0                     1.0
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# 0                 0.0      123.0       27.47          103.0           16.62
#
#    night_calls  night_charge  international_calls  international_charge  \
# 0        103.0         11.45                  3.0                   3.7
#
#    total_charge
# 0         59.24

# %%
model.predict(new_user)
# Out:
# array([0], dtype=int64)
